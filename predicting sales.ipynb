# %%
import pandas as pd
import numpy as np

# %%
train_1=pd.read_excel("Documents/train_1.xlsx")
train_1=pd.DataFrame(train_1)
train_1
# Out:
#      Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 0         CollgCr       Norm       Norm     1Fam     2Story            7
# 1         Veenker      Feedr       Norm     1Fam     1Story            6
# 2         CollgCr       Norm       Norm     1Fam     2Story            7
# 3         Crawfor       Norm       Norm     1Fam     2Story            7
# 4         NoRidge       Norm       Norm     1Fam     2Story            8
# 5         Mitchel       Norm       Norm     1Fam     1.5Fin            5
# 6         Somerst       Norm       Norm     1Fam     1Story            8
# 7          NWAmes       PosN       Norm     1Fam     2Story            7
# 8         OldTown     Artery       Norm     1Fam     1.5Fin            7
# 9         BrkSide     Artery     Artery   2fmCon     1.5Unf            5
# 10         Sawyer       Norm       Norm     1Fam     1Story            5
# 11        NridgHt       Norm       Norm     1Fam     2Story            9
# ...

# %%
train_1.describe()
# Out:
#        OverallQual  OverallCond     1stFlrSF     2ndFlrSF    GrLivArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      6.099315     5.575342  1162.626712   346.992466  1515.463699
# std       1.382997     1.112799   386.587738   436.528436   525.480383
# min       1.000000     1.000000   334.000000     0.000000   334.000000
# 25%       5.000000     5.000000   882.000000     0.000000  1129.500000
# 50%       6.000000     5.000000  1087.000000     0.000000  1464.000000
# 75%       7.000000     6.000000  1391.250000   728.000000  1776.750000
# max      10.000000     9.000000  4692.000000  2065.000000  5642.000000
#
#        BedroomAbvGr  TotRmsAbvGrd      SalePrice
# count   1460.000000   1460.000000    1460.000000
# mean       2.866438      6.517808  180921.195890
# std        0.815778      1.625393   79442.502883
# min        0.000000      2.000000   34900.000000
# 25%        2.000000      5.000000  129975.000000
# ...

# %% [markdown]
# ### Describing the overall view of the five-number summary statistics of the houses sales

# %% [markdown]
# - The house with the highest rate on the overall condition was the house with the highest sale, which is same as the one with the highest rate in overall quality
# - This means that the best looking houses around have the higher sale than the others ,does the neighourhood influence this as well?

# %%
# lets see how graphics interprets this
import seaborn as sns

# %%
sns.heatmap(train_1.corr(),annot=True,fmt='.2f')
sns.set()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(train_1['OverallQual'],train_1['SalePrice'],color='m')

# %%
plt.plot(train_1['GrLivArea'],train_1['SalePrice'],color='c');

# %% [markdown]
# **- I have to conclude that the 'Overall quality' and the 'GrLivArea' have a postive correlation with the Sale price.**

# %% [markdown]
# #### Overall quality VS Sale condition

# %%
qual=train_1["OverallQual"]
sales=train_1["SalePrice"]
plot_1=sns.scatterplot(sales,qual)
plot_1;

# %%
sns.pairplot(train_1)
sns.set()

# %% [markdown]
# #### Overall condition VS Sale condtion

# %%
cond=train_1["OverallCond"]
sales=train_1["SaleCondition"]
plot_1=sns.barplot(sales,cond)
plot_1;

# %% [markdown]
# #### Sale price VS sale condition

# %%
price_house=train_1["SalePrice"]
sales=train_1["SaleCondition"]
plot_1=sns.barplot(sales,price_house)
plot_1;

# %% [markdown]
# ### House style VS Sale price

# %%
style=train_1["HouseStyle"]
price=train_1["SalePrice"]
plot_2=sns.scatterplot(style,price,color="m")
plot_2;

# %% [markdown]
# - **The house with the highest purchase was a two-story building.**

# %%
quality=train_1['OverallQual']
liv=train_1['GrLivArea']

# %%
import numpy as np
features=quality,liv
np.reshape(features,(1460,2))
features
# Out:
# (0        7
#  1        6
#  2        7
#  3        7
#  4        8
#  5        5
#  6        8
#  7        7
#  8        7
#  9        5
#  10       5
#  11       9
#  12       5
#  13       7
#  14       6
#  15       7
#  16       6
#  17       4
#  18       5
#  19       5
#  20       8
#  21       7
#  22       8
#  23       5
#  24       5
#  25       8
#  26       5
#  27       8
#  28       5
#  29       4
#          ..
#  1430     5
#  1431     6
#  1432     4
#  1433     6
#  1434     5
#  1435     6
#  1436     4
#  1437     8
#  1438     6
#  1439     7
#  1440     6
#  1441     6
#  1442    10
#  1443     6
#  1444     7
#  1445     6
#  1446     5
#  1447     8
#  1448     4
#  1449     5
#  1450     5
#  1451     8
#  1452     5
#  1453     5
#  1454     7
#  1455     6
#  1456     6
#  1457     7
#  1458     5
#  1459     5
#  Name: OverallQual, Length: 1460, dtype: int64, 0       1710
#  1       1262
#  2       1786
#  3       1717
#  4       2198
#  5       1362
# ...

# %%
 y=train_1['SalePrice']
y

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf=RandomForestClassifier()
clf.fit(features,y)
# Out:
# C:\Users\betty123\OneDrive\Documents\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-3a019e90900b> in <module>
#       1 clf=RandomForestClassifier()
# ----> 2 clf.fit(features,y)
#
# ~\OneDrive\Documents\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# ~\OneDrive\Documents\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
# ...

# %%
import pandas as pd
train=pd.read_csv("Documents/train.csv")

# %%
train.head(15)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train=pd.DataFrame(train)

# %%
import seaborn as sns
sns.heatmap(train.corr(),annot=True,fmt='.2f')
sns.set()
